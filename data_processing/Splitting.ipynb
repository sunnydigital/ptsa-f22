# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('it_history.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'GICS Sector', 'GICS Sub-Industry', 'Symbol',
#        '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01',
#        '2013-05-01',
#        ...
#        '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#        '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-11-11'],
#       dtype='object', length=125)

# %%
val_num = int(np.round((len(df.columns[3:])*0.15)))
train_num = len(df.columns[3:])-val_num

# %%
val = df.iloc[:,3:val_num+3]
train = df.iloc[:,val_num+3:train_num+3]
test = df.iloc[:, train_num+3:]

# %%
val
# Out:
#    Symbol  2012-12-01  2013-01-01  2013-02-01  2013-03-01  2013-04-01  \
# 0     ADI   33.299622   34.807419   36.067642   37.362881   35.353691
# 1    ANSS   67.339996   73.599998   75.800003   81.419998   80.860001
# 2    ADSK   35.349998   38.880001   36.720001   41.250000   39.380001
# 3    NVDA    2.831782    2.831782    2.924175    2.981620    3.200071
# 4     HPQ    4.856634    5.680672    6.929663    8.202739    7.132774
# ..    ...         ...         ...         ...         ...         ...
# 61   JNPR   16.185179   18.415062   17.016239   15.255368   13.617930
# 62   SWKS   17.949310   21.167812   18.833511   19.478981   19.514351
# 63   MCHP   13.154645   13.501779   14.720770   14.984516   14.841885
# 64   KLAC   30.347883   34.891178   34.795860   33.750774   34.717091
# 65     MU    6.290163    7.500572    8.314127    9.901549    9.345952
#
#     2013-05-01  2013-06-01  2013-07-01  2013-08-01  2013-09-01  2013-10-01  \
# ...

# %%
train
# Out:
#      2014-06-05  2014-06-06  2014-06-09  2014-06-10  2014-06-11  2014-06-12  \
# 0     97.499718   98.710129   98.943863   98.952217   98.367859   97.382866
# 1     65.485001   65.675003   65.394997   65.339996   65.970001   65.510002
# 2      8.438933    8.462684    8.466642    8.427058    8.423101    8.431018
# 3     23.795589   23.933800   23.803265   23.611301   23.365599   23.534515
# 4     19.926353   20.061319   19.969301   19.920219   19.772978   19.772978
# ..          ...         ...         ...         ...         ...         ...
# 115   33.863014   34.392593   34.892746   34.892746   34.784882   34.711334
# 116   59.890003   59.682178   60.173389   60.834633   60.154507   58.822563
# 117  179.537231  182.810486  184.096390  183.035950  186.868683  186.209015
# 118   40.313801   40.239384   39.807747   39.785404   39.093292   39.137947
# 119   40.542370   40.178623   39.938553   40.076775   39.793056   40.004036
#
# ...

# %%
train.to_csv('train_daily.csv')
test.to_csv('test_daily.csv')
val.to_csv('val_daily.csv')
