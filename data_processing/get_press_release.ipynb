# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
msft.news
# Out:
# [{'uuid': '645c4ce8-44e0-3ab3-bc4d-d818730cf503',
#   'title': 'Union says Microsoft will recognize unit of videogame testers',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/union-says-microsoft-recognize-unit-220905820.html',
#   'providerPublishTime': 1670278145,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/zW8Vtivd_9PBTIN7TxthIA--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/c4db74e6bc3719afccee540aad0a9ef8',
#      'width': 800,
#      'height': 533,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/D6tSvekgp_GpYUSd5yuV0g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/c4db74e6bc3719afccee540aad0a9ef8',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'ATVI']},
#  {'uuid': 'bf6b0545-befa-3bb6-a9d6-974e4e30bbce',
# ...

# %%
msft.calendar
# Out:
#                                     0                    1
# Earnings Date     2023-01-23 10:59:00  2023-01-27 12:00:00
# Earnings Average                 2.29                 2.29
# Earnings Low                     2.23                 2.23
# Earnings High                    2.36                 2.36
# Revenue Average           52969300000          52969300000
# Revenue Low               52389000000          52389000000
# Revenue High              53475000000          53475000000
