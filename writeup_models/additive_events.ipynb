# %% [markdown]
# ## Package Installaion

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (0.13.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: scipy>=1.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from statsmodels) (1.23.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from statsmodels) (1.5.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pandas>=0.25->statsmodels) (2022.4)
# Requirement already satisfied: six in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install neuralprophet
# %pip install matplotlib
# %pip install seaborn
# %pip install pickle
# Out:
# Requirement already satisfied: neuralprophet in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (0.5.0rc2)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (1.23.3)
# Requirement already satisfied: pytorch-lightning==1.7.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (1.7.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (1.13.0)
# Requirement already satisfied: torchmetrics==0.9.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (0.9.3)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (2.4.0)
# Requirement already satisfied: holidays>=0.11.3.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (0.17.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (2.8.2)
# Requirement already satisfied: rich==12.4.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (12.4.4)
# Requirement already satisfied: plotly>=4.14.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (5.11.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (0.0.9)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (8.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from neuralprophet) (3.6.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (2022.11.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (6.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (0.3.2)
# Requirement already satisfied: packaging>=17.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (4.4.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (2.11.0)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pytorch-lightning==1.7.4->neuralprophet) (4.64.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from rich==12.4.4->neuralprophet) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from rich==12.4.4->neuralprophet) (0.9.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from convertdate>=2.1.2->neuralprophet) (0.5.11)
# Requirement already satisfied: korean-lunar-calendar in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from holidays>=0.11.3.1->neuralprophet) (0.3.1)
# Requirement already satisfied: hijri-converter in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from holidays>=0.11.3.1->neuralprophet) (2.2.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (6.16.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (4.0.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (8.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.5.0)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from LunarCalendar>=0.0.9->neuralprophet) (4.1.3)
# Requirement already satisfied: pytz in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from LunarCalendar>=0.0.9->neuralprophet) (2022.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (1.0.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from plotly>=4.14.3->neuralprophet) (8.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from python-dateutil>=2.8.0->neuralprophet) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (3.8.3)
# Requirement already satisfied: requests in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (2.28.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (24.0.1)
# Requirement already satisfied: nest-asyncio in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (7.4.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (1.6.3)
# Requirement already satisfied: psutil in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (5.9.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.1.6)
# Requirement already satisfied: decorator in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.18.1)
# Requirement already satisfied: colorama in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.4.6)
# Requirement already satisfied: pickleshare in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (3.0.31)
# Requirement already satisfied: backcall in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.5.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (2.15.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (3.20.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (65.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (1.51.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (2.2.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (1.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (6.0.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (1.8.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (4.11.1)
# Requirement already satisfied: entrypoints in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.4)
# Requirement already satisfied: wcwidth in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.4->neuralprophet) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (2.1.1)
# Requirement already satisfied: pure-eval in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (2.0.8)
# Requirement already satisfied: executing in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (1.1.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (303)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning==1.7.4->neuralprophet) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (3.6.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (0.12.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from seaborn) (1.5.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from pandas>=0.25->seaborn) (2022.4)
# Requirement already satisfied: six>=1.5 in c:\users\sunny\anaconda3\envs\ptsa\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %% [markdown]
# ## Package Importation

# %%
from neuralprophet import NeuralProphet, set_random_seed, set_log_level; set_random_seed(314159); set_log_level("ERROR", "INFO")
from neuralprophet.df_utils import make_future_df, fill_linear_then_rolling_avg, add_missing_dates_nan

import pandas as pd
import numpy as np

import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True); sns.set_style("whitegrid")

import time

from collections import defaultdict

import copy

import pickle

# %% [markdown]
# ## Reading Data
#
# Below we read in the data for train, val and test as well as the associated historical dataframe

# %%
IT_sector_historical = pd.read_csv('../data_processing/it_history.csv', index_col=0)

# %%
idx2col = {
    'index': 'ds',
    0: 'GEN',
    1: 'MSI',
    2: 'JKHY',
    3: 'APH',
    4: 'IBM',
    5: 'AKAM',
    6: 'MSFT',
    7: 'STX',
    8: 'AAPL',
    9: 'AMAT',
    10: 'TEL'
}

# %%
train = pd.read_csv('../data_processing/train_final.csv', index_col=0).T.reset_index(level=0).rename(columns=idx2col)
val = pd.read_csv('../data_processing/val_final.csv', index_col=0).T.iloc[1:,:].reset_index(level=0).rename(columns=idx2col)
test = pd.read_csv('../data_processing/test_final.csv', index_col=0).T.reset_index(level=0).rename(columns=idx2col)

# %%
earnings_10yr_df = pd.read_csv('../data_processing/earnings_10yr_past_future_df.csv')

# %% [markdown]
# ## Auxiliary Plotting Functions

# %%
def plot_forecast(model, data, periods=0, historic_pred=True, highlight_steps_ahead=None, xlabel='Date', ylabel=None, title=None):
    
    future = model.make_future_dataframe(data, 
                                         periods=periods, 
                                         n_historic_predictions=historic_pred)
    forecast = model.predict(future)
    
    fig, ax = plt.subplots(figsize=(14,10))

    if highlight_steps_ahead is not None:
        model = model.highlight_nth_step_ahead_of_each_forecast(highlight_steps_ahead)
        model.plot_last_forecast(forecast, ax=ax, xlabel=xlabel, ylabel=ylabel)
        ax.set_title(title, fontsize=20, fontweight="bold")

    else:    
        model.plot(forecast, ax=ax, xlabel=xlabel, ylabel=ylabel)
        ax.set_title(title, fontsize=20, fontweight="bold")

# %%
def plot_validation(metrics_df, metrics = ['SmoothL1Loss', 'MAE', 'RMSE']):
    met_len = len(metrics)

    fig, axs = plt.subplots(ncols=len(metrics), nrows=1, sharex=True, sharey=True, figsize=(8*met_len, 8))
    fig.suptitle('Validation Metrics', fontsize=20, y=0.95)

    if met_len == 1:
        metric = metrics[0]
        axs.plot(metrics_df[metric], 'ob', linewidth=6, label='Training Loss', markersize='3')
        axs.plot(metrics_df[f'{metric}_val'], 'r', linewidth=2, label='Validation Loss')

        axs.set_xlabel('Training Loss')
        axs.set_ylabel('Validation Loss')
        axs.set_title(metric)
        axs.legend()
    else:
        for metric, ax in zip(metrics, axs.ravel()):
            ax.plot(metrics_df[metric], 'ob', linewidth=6, label='Training Loss', markersize='3')
            ax.plot(metrics_df[f'{metric}_val'], 'r', linewidth=2, label='Validation Loss')

            ax.set_xlabel('Training Loss')
            ax.set_ylabel('Validation Loss')
            ax.set_title(metric)
            ax.legend()

# %% [markdown]
# ## Base Model (Train)
# ---
#
# Below we define the base model alongside the addition of country holidays in the US. This acts as the 'base model' with which we will conduct the analysis of the additive events futher:

# %%
base_model = NeuralProphet(
    growth='discontinuous',  # Determine trend types: ‘linear’, ‘discontinuous’, ‘off’
    changepoints=None, # list of dates that may include change points (None -> automatic )
    n_changepoints=52, # Number of weeks in a month, looks at a potential changepoint evey month
    trend_reg=0, # Changed to 0 for no flexibility in selection of changepoints
    trend_reg_threshold=False, # Requires regularization for trend to be changed
    yearly_seasonality=True, # Automatically fits yearly seasonality
    weekly_seasonality='auto', # Automatically fits weekly seasonality
    daily_seasonality='auto', # Automatically fits daily seasonality
    seasonality_mode='additive', # Additional (adds) seasonality instead of multiplicative (multiplies) seasonality
    seasonality_reg=0, # Due to the dataset being based on bike shares, visually will be very impacted by seasonality: set at maximum
    n_forecasts=1, # Set at default 1 for forecasting one step ahead
    n_lags=7, # To include 7 days worth of AR lag
    num_hidden_layers=0, # 8 hidden layers for the network
    )
base_model.add_country_holidays('US')

# %% [markdown]
# ## Additive Events

# %%
CES_dates_df = pd.DataFrame(
    {
        "event": "CES Show",
        "ds": pd.to_datetime(
            [
                "2012-01-11",
                "2013-01-10",
                "2013-01-09",
                "2014-01-05",
                "2015-01-09",
                "2016-01-07",
                "2017-01-06",
                "2018-01-10",
                "2019-01-09",
                "2020-01-08",
                "2021-01-12",
                "2022-01-05",
                "2023-01-06",
            ]
        ),
    }
)

AAPL_dates_df = pd.DataFrame(
    {
        "event": "AAPL Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['aapl']
        ),
    }
)

META_dates_df = pd.DataFrame(
    {
        "event": "META Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['meta']
        ),
    }
)

GOOG_dates_df = pd.DataFrame(
    {
        "event": "GOOG Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['goog']
        ),
    }
)

NFLX_dates_df = pd.DataFrame(
    {
        "event": "NFLX Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['nflx']
        ),
    }
)

AMZN_dates_df = pd.DataFrame(
    {
        "event": "AMZN Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['amzn']
        ),
    }
)

MSFT_dates_df = pd.DataFrame(
    {
        "event": "MSFT Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['msft']
        ),
    }
)

NVDA_dates_df = pd.DataFrame(
    {
        "event": "NVDA Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['nvda']
        ),
    }
)

AMD_dates_df = pd.DataFrame(
    {
        "event": "AMD Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['amd']
        ),
    }
)

INTC_dates_df = pd.DataFrame(
    {
        "event": "INTC Earnings",
        "ds": pd.to_datetime(
            earnings_10yr_df['intc']
        ),
    }
)

# %% [markdown]
# ### Create Events Dataframe for IT Sector

# %%
event_names = [
    'CES Show',
    'AAPL Earnings', 
    'META Earnings', 
    'GOOG Earnings', 
    'NFLX Earnings', 
    'AMZN Earnings',
    'MSFT Earnings',
    'NVDA Earnings',
    'AMD Earnings',
    'INTC Earnings',
]

# %%
events_df = pd.concat(
    (
        CES_dates_df,
        AAPL_dates_df,
        META_dates_df,
        GOOG_dates_df,
        NFLX_dates_df,
        AMZN_dates_df,
        MSFT_dates_df,
        NVDA_dates_df,
        AMD_dates_df,
        INTC_dates_df
    ),
)

# %%
events_df
# Out:
#             event         ds
# 0        CES Show 2012-01-11
# 1        CES Show 2013-01-10
# 2        CES Show 2013-01-09
# 3        CES Show 2014-01-05
# 4        CES Show 2015-01-09
# ..            ...        ...
# 43  INTC Earnings 2013-01-17
# 44  INTC Earnings 2012-10-16
# 45  INTC Earnings 2012-07-17
# 46  INTC Earnings 2012-04-17
# 47  INTC Earnings 2012-01-19
#
# [445 rows x 2 columns]

# %%
# %pwd
# Out:
# '/Users/sunnyson/Library/CloudStorage/OneDrive-Personal/Documents/GitHub/pTSA_F22/writeup_models'

# %%
has_historical_df = False
read_in_model_and_metrics = False

models_dict = dict()

for symbol in train.columns:
    if symbol == 'ds': continue

    if read_in_model_and_metrics:
        with open(f'./additive_files/model_pickles/{symbol}_model.pkl', 'rb') as f:
            model = pickle.load(f)
        with open(f'./additive_files/model_metrics/{symbol}_metrics.csv', 'rb') as f:
            metrics = pd.read_csv(f)
        with open(f'./additive_files/model_historical_train_df/{symbol}_historical_train_df.csv', 'rb') as f:
            historical_train_df = pd.read_csv(f)
        with open(f'./additive_files/model_historical_val_df/{symbol}_historical_val_df.csv', 'rb') as f:
            historical_val_df = pd.read_csv(f)
        models_dict[symbol] = [model, metrics, historical_train_df, historical_val_df]
        
    else:
        model = copy.deepcopy(base_model)
        model = model.add_events(event_names, lower_window=-1, upper_window=1)

        train_with_dates_df = train[[symbol, 'ds']].rename(columns={symbol: 'y'})
        val_with_dates_df = val[[symbol, 'ds']].rename(columns={symbol: 'y'})

        historical_train_df = model.create_df_with_events(train_with_dates_df, events_df)
        historical_val_df = model.create_df_with_events(val_with_dates_df, events_df)

        metrics = model.fit(
            df=historical_train_df,
            freq='D',
            validation_df=historical_val_df,
            progress='bar'
        )

        pickle.dump(model, open(f'./additive_files/model_pickles/{symbol}_model.pickle', 'wb'))
        historical_train_df.to_csv(open(f'./additive_files/model_historical_train_df/{symbol}_historical_val_df.csv', 'wb'))
        historical_val_df.to_csv(open(f'./additive_files/model_historical_val_df/{symbol}_historical_val_df.csv', 'wb'))
        pickle.dump(metrics, open(f'./additive_files/model_metrics/{symbol}_metrics.csv', 'wb'))
        
        models_dict[symbol] = [model, metrics, historical_train_df, historical_val_df]
        pickle.dump(models_dict, open('./additive_files/model_pickles/models_dict.pickle', 'wb'))

# %% [markdown]
# ## Creating & Predicting Into Future
# ---
#
# Note with the above `models_dict`, the storage of each `Symbol`'s data are as follows in a `dict` format:
#
# `model = 0`
#
# `metrics = 1`
#
# `historical_train_df = 2`
#
# `historical_val_df = 3`
#
# Below we show one example of a company "JKHY" and plotting the outputs associated

# %%
model = models_dict['JKHY'][0]
metrics = models_dict['JKHY'][1]
historical_train_df = models_dict['JKHY'][2]
historical_val_df = models_dict['JKHY'][3]

# %%
future = model.make_future_dataframe(df=historical_train_df, events_df=events_df, periods=365, n_historic_predictions=len(train))
forecast = model.predict(df=future)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)

# %%
model.plot(forecast)

# %% [markdown]
# ## Plotting Subplots of Additive-Events
# ---

# %%
fig, axs = plt.subplots(3, 4, figsize = (100,60))

for i, ax in zip(range(12), axs.flatten()):
    if i == 11: 
        ax.axis('off')
        continue
    symbol = idx2col[i]
    
    model = models_dict[symbol][0]
    metrics = models_dict[symbol][1]
    historical_train_df = models_dict[symbol][2]
    historical_val_df = models_dict[symbol][3]
    
    future = model.make_future_dataframe(df=historical_train_df, events_df=events_df, periods=365, n_historic_predictions=len(train))
    forecast = model.predict(df=future)
    
    ax.scatter(forecast['ds'],forecast['y'], c = 'black')
    ax.plot(forecast['ds'],forecast['yhat1'])
    ax.set_title(symbol,fontweight='bold', size=80)
    
plt.show()
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:2060: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(future_df)
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/df_utils.py:806: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "ds"] = pd.to_datetime(df.loc[:, "ds"])
#
# WARNING - (py.warnings._showwarnmsg) - /Users/sunnyson/opt/anaconda3/envs/pTSA/lib/python3.10/site-packages/neuralprophet/forecaster.py:1406: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_end_to_append)
# "industry_symbol['Symbol']\nfor i in range(6):\n    for j in range(10):\n        ind = 6*i + j \n        symbol = industry_symbol['Symbol'][ind]\n        filename = '../model/model_store/'+symbol+'_model.pickle'\n        model = pickle.load(open(filename, 'rb'))\n        test_inp = pd.DataFrame(test[symbol_to_index_map[symbol]])\n        test_inp=test_inp.reset_index()\n        test_inp=test_inp.rename(columns = {'index' : 'ds', symbol_to_index_map[symbol]:'y'})\n        future = model.make_future_dataframe(df=test_inp, periods=365, n_historic_predictions=len(test_inp))\n        forecast = model.predict(df=test_inp)\n        ax[i,j].scatter(forecast['ds'],forecast['y'], c = 'black')\n        ax[i,j].plot(forecast['ds'],forecast['yhat1'])\n        ax[i,j].set_title(symbol)\n\nplt.show()"

# %% [markdown]
# ## Deprecated Code with Multiple Industries

# %%
has_historical_df = False
read_in_model_and_metrics = False
model_dict = defaultdict()

for industry, symbols in industry_to_symbol_map.items():
    model_dict[industry] = defaultdict()
    for symbol in symbols:
        model_dict[industry][symbol] = {
            'model': None,
            'metrics': None,
        }

        if read_in_model_and_metrics:
            model_dict[industry][symbol]['model'] = pickle.load('./model/' + industry_to_folder_map[industry] + '/' + symbol + '/model.pkl')
            model_dict[industry][symbol]['metrics'] = pickle.load('./model/' + industry_to_folder_map[industry] + '/' + symbol + '/metrics.pkl')
        else:
            model = base_model
            # model.add_seasonality(name='monthly', period=30.5, fourier_order=5, prior_scale=0.1)
            model = model.add_events(additive_events[industry])

            ## Reads in historical_df if has_historical_df else creates & writes historical_df
            if has_historical_df:
                historical_df = pd.read_csv('./model/' + industry_to_folder_map[industry] + '/' + symbol + '/historical_df.csv')
            else:
                historical_df = model.create_df_with_events(train[:, symbol_to_index_map[symbol]], additive_events[industry])
                historical_df.to_csv('./model/' + industry_to_folder_map[industry] + '/' + symbol + '/historical_df.csv', index=False)
            
            metrics = model.fit(historical_df, freq="D", validation_df=val[symbol_to_index_map[symbol]])
            
            ## Updating defaultdict of mdoels
            model_dict[industry][symbol]['model'] = model
            model_dict[industry][symbol]['metrics'] = metrics

            ## Pickling model and metrics
            model_path = './model/' + industry_to_folder_map[industry] + '/' + symbol + '/model'
            metrics_path = './model/' + industry_to_folder_map[industry] + '/' + symbol + '/metrics'

            pickle.dump(model, model_path)
            pickle.dump(metrics, metrics_path)
